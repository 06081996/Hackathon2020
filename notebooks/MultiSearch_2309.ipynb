# %%
import pandas as pd 
import numpy as np
import os 
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import openpyxl as pxl
from project_lib import Project
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/spark/shared/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_36060ea8de5843bf8f2776d17d73596f = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='2cPyOVh_yem74fLHSBhdDXa-scXY-a10q34eKyqbARYz',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_36060ea8de5843bf8f2776d17d73596f.get_object(Bucket='nlp-donotdelete-pr-kdy6u2zq9kjuiw',Key='Final_5_9.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_0 = pd.read_excel(body)
df_data_0.head()
# Out:
#    Application ID Application Name Module ID      Module Name  \
# 0            1220           MERLIN       M12  Merlin vs Seqel
# 1            1220           MERLIN       M12  Merlin vs Seqel
# 2            1220           MERLIN       M12  Merlin vs Seqel
# 3            1220           MERLIN       M12  Merlin vs Seqel
# 4            1220           MERLIN       M12  Merlin vs Seqel
#
#    Functionaliyt ID            Functionality Name  Release ID Release Name  \
# 0               131  Merlin vs Seqel Breach Excel           1       RTI100
# 1               131  Merlin vs Seqel Breach Excel           1       RTI100
# 2               131  Merlin vs Seqel Breach Excel           1       RTI100
# 3               131  Merlin vs Seqel Breach Excel           1       RTI100
# 4               131  Merlin vs Seqel Breach Excel           1       RTI100
#
#    Defect ID  Type of Defect Defect Reason  \
# 0     1000.0            Data   Environment
# 1     1001.0              UI          Code
# 2     1002.0            Data        Design
# 3     1003.0  Business Logic        Design
# 4     1004.0              UI          Data
#
#                                                                          Defect Description  \
# 0            Merlin vs Seqel Breach Excel has faulty operations which is missing in excel\n
# 1  Merlin vs Seqel Breach Excel is not downloading for database which is missing in excel\n
# 2                Merlin vs Seqel Breach Excel shows incorrect code and filters are faulty\n
# 3         Merlin vs Seqel Breach Excel has defect in documentation which is missing in UI\n
# 4  Merlin vs Seqel Breach Excel is not downloading for testing modules which is incorrect\n
#
#    Severity  \
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
#                                                                       RCA  \
# 0          Code was corrected after confirming the changes with developer
# 1  New requirements were added to the project afer confirming with Client
# 2     Data in the table - RECON_SAMPLE corrected after confirming with BA
# 3        New files created for handling new data coming into the database
# 4  Data format was changed to fetch the data using code from the database
#
#   Release Date Defect Creation Date Defect Fix Date
# 0   2019-01-01           2019-01-28      2019-02-17
# 1   2019-01-01           2019-01-16      2019-01-27
# 2   2019-01-01           2019-01-13      2019-02-14
# 3   2019-01-01           2019-02-16      2019-03-21
# 4   2019-01-01           2019-01-14      2019-02-26

# %%
df_data_1=df_data_0
df_data_0=[]

# %%
body = client_36060ea8de5843bf8f2776d17d73596f.get_object(Bucket='nlp-donotdelete-pr-kdy6u2zq9kjuiw',Key='input.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_0 = pd.read_excel(body)
df_data_0.head()
# Out:
#                    string  Ticket _id
# 0   export is not working  INC0012345
# 1  pop up is not working    INC006789

# %%
df_data_3=df_data_0

# %%
print(df_data_3.shape[0])
# Out:
# 2

# %%
for i in range(df_data_3.shape[0]):
    print(df_data_3['string'][i])
# Out:
# export is not working
# pop up is not working

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/spark/shared/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/spark/shared/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
project = Project(sc,"34bb1b6c-a1e9-40ae-9fef-9c20596f29db","p-46ef0f1e255b4911f8cc56531f6dc5b301c5cc6f")

# %%
SearchStr=[]
#SearchStr=['pearl Operational Loss','FFS Recon','FDL mapping','LCS']
#SearchStr=['data export functionality failing','pop up screen is not loading']
SearchStr=['operation loss']
#SearchStr=['////']
#TOD="Business Logic"
def srchstr(SearchStr):
    
    for i in range(df_data_3.shape[0]):
        df=df_data_1.copy()
        SearchStr=str(df_data_3['string'][i])
        filename=str(df_data_3['Ticket _id'][i])
        print(SearchStr)
        if(not re.sub('[^A-Za-z0-9]+', '', SearchStr)):

            print("invalid input")
            Final=[]
            break
        ##df = pd.read_excel("final.xlsx")
        Final=df.copy()
        SearchStr=re.sub("(\\d|\\W)+"," ",SearchStr)
        df = df['Defect Description']
        df = pd.DataFrame({'Desc':df})
        k=0
        for a in df.index:
            X=df['Desc'][a]
            # tokenization 
            X_list=[]
            Y_list=[]
            X_list = word_tokenize(X.lower())  
            Y_list = word_tokenize(SearchStr.lower()) 

          # Fetching all stop words
            sw = stopwords.words('english')  
            V1 =[];V2 =[] 

            # Stop word removal 
            X_set = {lemmatizer.lemmatize(w) for w in X_list if not w in sw}  
            Y_set = {lemmatizer.lemmatize(w) for w in Y_list if not w in sw} 

            UV = X_set.union(Y_set)  
            for w in UV:

                if w in X_set: V1.append(1) 

                else: V1.append(0) 
                if w in Y_set: V2.append(1) 
                else: V2.append(0) 
                c = 0
        # Calculating cosine similarity  
            for i in range(len(UV)): 

                c+= V1[i]*V2[i] 
                #print(c)
            cosine = c / float((sum(V1)*sum(V2))**0.5)
        #print(cosine)
            Final.loc[Final['Defect Description']== X,'Similarity']=cosine   
        pd.options.display.max_colwidth=1000
        Final=Final[(Final['Similarity']>0) & (Final['Type of Defect']==Final['Type of Defect'])].sort_values(by='Similarity',ascending=False)
        Final = Final.drop_duplicates(subset=['Defect Description'], keep='first')
        Final = Final[['Release Name','Defect ID','Defect Description','RCA']].head(3)

        project.save_data(file_name = filename+".csv",data = Final.to_csv(index=False),overwrite=True)

# %%
srchstr(SearchStr)
# Out:
# export is not working
# pop up is not working
